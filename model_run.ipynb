# %%
import glob
import numpy as np
import os

# %%
def classify_folder(in_folder, model):
    #get a folder of npz files, return a dict of names->classifications
    files = glob.glob(os.path.join(in_folder, 'IMG*.npz'))
    result_dict = dict()
    for npz_file in files:
        result_dict[npz_file] = apply_model_to_npz(npz_file, model)
    return result_dict

def apply_model_to_npz(npz_file, model):
    #read in npz file
    #inference step
    #return result

# %%
test_folder = r'/home/disk/eos4/jkcm/Data/MEASURES/MODIS_downloads/sample/data'

# %%
os.listdir(test_folder)
# Out:
# ['sample_manifest.csv',
#  'sample_manifest_allfiles.csv',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0256_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0384_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0512_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0640_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0768_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_0896_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0000_index_1024_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0128_index_0128_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0128_index_0256_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0128_index_0384_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0128_index_0512_Block128x128.npz',
#  'IMG_MYD021KM.A2015182.0045.061_index_0128_index_0640_Block128x128.npz',
# ...
